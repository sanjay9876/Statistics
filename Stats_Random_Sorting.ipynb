# %%
import random

# %%
myNum = random.random()
print(myNum)
# Out:
# 0.6167873926409758

# %%
# creates random number between 10 and 20,
# includes 10 and excludes 20
myNum = random.randint(10,20)
print(myNum)
# Out:
# 13

# %%
myNum = random.randint(10,20)
print(myNum)
# Out:
# 18

# %%
myNum = random.randrange(10,20,2) # only even random numbers
print(myNum)
# Out:
# 18

# %%
myNum = random.randrange(10,20,2) # only even random numbers
print(myNum)
# Out:
# 16

# %% [markdown]
# # Choice -- Random selection from list

# %%
dice = ["one","two","three","four","five","six"]

# %%
player1 = random.choice(dice)
print(player1)
# Out:
# three

# %%
player2 = random.choice(dice)
print(player2)
# Out:
# one

# %% [markdown]
# # Shuffle the list in place

# %%
random.shuffle(dice)
print(dice)
# Out:
# ['four', 'two', 'one', 'three', 'five', 'six']

# %%
random.shuffle(dice)
print(dice)
# Out:
# ['four', 'two', 'five', 'six', 'one', 'three']

# %% [markdown]
# # Sampling

# %%
mySample = random.sample(dice,4)
print(mySample)
# Out:
# ['six', 'two', 'five', 'three']

# %% [markdown]
# # Use random number generator to create list of
# # 100 integers between 0 and 100

# %%
numbers = 100
numbers_100a = []
for kk in range(numbers):
    myNum = random.randint(0,100) # includes 0, excludes 100
    numbers_100a.append(myNum)

# %%
print(numbers_100a[0:10])
# Out:
# [94, 65, 96, 45, 14, 33, 30, 75, 48, 61]

# %%
numbers_100b = [random.randint(0,100) for _ in range(100)]
# _ is Python's throwaway variable

# %%
print(numbers_100b[0:10])
# Out:
# [82, 81, 81, 26, 16, 93, 84, 11, 31, 95]

# %%
print("Number of elements in the list ==>",len(numbers_100a))
# Out:
# Number of elements in the list ==> 100

# %% [markdown]
# # Sum all elements in the list

# %%
# Add all list elements
mySum = sum(numbers_100a)
print("Sum of all elements ==>",mySum)
# Out:
# Sum of all elements ==> 5292

# %%
print(numbers_100a)
# Out:
# [94, 65, 96, 45, 14, 33, 30, 75, 48, 61, 48, 96, 54, 29, 42, 66, 75, 46, 25, 94, 24, 6, 3, 72, 92, 66, 82, 61, 73, 41, 16, 62, 94, 77, 47, 70, 28, 73, 67, 100, 5, 24, 30, 18, 99, 60, 14, 27, 53, 15, 68, 12, 81, 77, 47, 91, 84, 21, 11, 98, 2, 100, 44, 91, 28, 75, 100, 19, 70, 89, 36, 13, 59, 60, 41, 75, 1, 77, 87, 6, 46, 63, 36, 28, 95, 10, 96, 55, 83, 8, 23, 59, 62, 8, 68, 5, 90, 78, 3, 78]

# %% [markdown]
# # Sorting

# %%
numbers_100a.sort() # in-place ascending sort
print(numbers_100a)
# Out:
# [1, 2, 3, 3, 5, 5, 6, 6, 8, 8, 10, 11, 12, 13, 14, 14, 15, 16, 18, 19, 21, 23, 24, 24, 25, 27, 28, 28, 28, 29, 30, 30, 33, 36, 36, 41, 41, 42, 44, 45, 46, 46, 47, 47, 48, 48, 53, 54, 55, 59, 59, 60, 60, 61, 61, 62, 62, 63, 65, 66, 66, 67, 68, 68, 70, 70, 72, 73, 73, 75, 75, 75, 75, 77, 77, 77, 78, 78, 81, 82, 83, 84, 87, 89, 90, 91, 91, 92, 94, 94, 94, 95, 96, 96, 96, 98, 99, 100, 100, 100]

# %%
numbers_100a.sort(reverse=True) # in-place descending sort
print(numbers_100a)
# Out:
# [100, 100, 100, 99, 98, 96, 96, 96, 95, 94, 94, 94, 92, 91, 91, 90, 89, 87, 84, 83, 82, 81, 78, 78, 77, 77, 77, 75, 75, 75, 75, 73, 73, 72, 70, 70, 68, 68, 67, 66, 66, 65, 63, 62, 62, 61, 61, 60, 60, 59, 59, 55, 54, 53, 48, 48, 47, 47, 46, 46, 45, 44, 42, 41, 41, 36, 36, 33, 30, 30, 29, 28, 28, 28, 27, 25, 24, 24, 23, 21, 19, 18, 16, 15, 14, 14, 13, 12, 11, 10, 8, 8, 6, 6, 5, 5, 3, 3, 2, 1]

# %%
print(numbers_100b)
# Out:
# [82, 81, 81, 26, 16, 93, 84, 11, 31, 95, 34, 94, 36, 94, 74, 3, 75, 51, 31, 96, 65, 64, 59, 12, 37, 96, 2, 84, 16, 56, 14, 38, 85, 90, 10, 94, 46, 23, 7, 44, 61, 5, 0, 87, 56, 47, 62, 23, 64, 18, 74, 97, 49, 70, 100, 43, 85, 88, 79, 76, 47, 20, 9, 20, 91, 62, 33, 10, 97, 73, 30, 55, 65, 92, 31, 52, 35, 83, 51, 78, 1, 30, 45, 65, 11, 97, 17, 76, 74, 12, 78, 78, 82, 51, 33, 100, 24, 100, 37, 22]

# %%
sorted_b = sorted(numbers_100b)
print(sorted_b)
# Out:
# [0, 1, 2, 3, 5, 7, 9, 10, 10, 11, 11, 12, 12, 14, 16, 16, 17, 18, 20, 20, 22, 23, 23, 24, 26, 30, 30, 31, 31, 31, 33, 33, 34, 35, 36, 37, 37, 38, 43, 44, 45, 46, 47, 47, 49, 51, 51, 51, 52, 55, 56, 56, 59, 61, 62, 62, 64, 64, 65, 65, 65, 70, 73, 74, 74, 74, 75, 76, 76, 78, 78, 78, 79, 81, 81, 82, 82, 83, 84, 84, 85, 85, 87, 88, 90, 91, 92, 93, 94, 94, 94, 95, 96, 96, 97, 97, 97, 100, 100, 100]

# %% [markdown]
# # Matplotlib Plotting

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,5,7,-8,10]) # can be any list
plt.show()

# %%
plt.plot(numbers_100b) # can be any list
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(numbers_100b) # can be any list
plt.show()

# %%
plt.plot(numbers_100b, 'o', color='black')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(numbers_100b, 'o', color='black')
plt.show()
